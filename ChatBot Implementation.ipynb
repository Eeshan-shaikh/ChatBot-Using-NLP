# %%
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Eshan123\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        "tag": "greeting",
        "patterns": ["Hi", "Hello", "Hey", "How are you", "What's up"],
        "responses": ["Hi there", "Hello", "Hey", "I'm fine, thank you", "Nothing much"]
    },
    {
        "tag": "goodbye",
        "patterns": ["Bye", "See you later", "Goodbye", "Take care"],
        "responses": ["Goodbye", "See you later", "Take care"]
    },
    {
        "tag": "thanks",
        "patterns": ["Thank you", "Thanks", "Thanks a lot", "I appreciate it"],
        "responses": ["You're welcome", "No problem", "Glad I could help"]
    },
    {
        "tag": "about",
        "patterns": ["What can you do", "Who are you", "What are you", "What is your purpose"],
        "responses": ["I am a chatbot", "My purpose is to assist you", "I can answer questions and provide assistance"]
    },
    {
        "tag": "help",
        "patterns": ["Help", "I need help", "Can you help me", "What should I do"],
        "responses": ["Sure, what do you need help with?", "I'm here to help. What's the problem?", "How can I assist you?"]
    },
    {
        "tag": "age",
        "patterns": ["How old are you", "What's your age"],
        "responses": ["I don't have an age. I'm a chatbot.", "I was just born in the digital world.", "Age is just a number for me."]
    },
    {
        "tag": "weather",
        "patterns": ["What's the weather like", "How's the weather today"],
        "responses": ["I'm sorry, I cannot provide real-time weather information.", "You can check the weather on a weather app or website."]
    },
    {
        "tag": "budget",
        "patterns": ["How can I make a budget", "What's a good budgeting strategy", "How do I create a budget"],
        "responses": ["To make a budget, start by tracking your income and expenses. Then, allocate your income towards essential expenses like rent, food, and bills. Next, allocate some of your income towards savings and debt repayment. Finally, allocate the remainder of your income towards discretionary expenses like entertainment and hobbies.", "A good budgeting strategy is to use the 50/30/20 rule. This means allocating 50% of your income towards essential expenses, 30% towards discretionary expenses, and 20% towards savings and debt repayment.", "To create a budget, start by setting financial goals for yourself. Then, track your income and expenses for a few months to get a sense of where your money is going. Next, create a budget by allocating your income towards essential expenses, savings and debt repayment, and discretionary expenses."]
    },
    {
        "tag": "credit_score",
        "patterns": ["What is a credit score", "How do I check my credit score", "How can I improve my credit score"],
        "responses": ["A credit score is a number that represents your creditworthiness. It is based on your credit history and is used by lenders to determine whether or not to lend you money. The higher your credit score, the more likely you are to be approved for credit.", "You can check your credit score for free on several websites such as Credit Karma and Credit Sesame."]
    },
    {
       "tag": "joke",
        "patterns": ["Tell me a joke", "Make me laugh", "Do you know any jokes?"],
        "responses": ["Why don't scientists trust atoms? Because they make up everything!", "I told my computer I needed a break, and now it won't stop sending me KitKat ads."]
    },
    {
        "tag": "news",
        "patterns": ["What's the latest news?", "Tell me the news", "Any updates on current events?"],
        "responses": ["I can't provide real-time news, but you can check news websites for the latest updates.", "For the latest news, consider visiting BBC or CNN."]
    },
    {
        "tag": "Recommendations",
        "patterns": ["Can you recommend a book?", "Suggest a movie", "What should I watch?"],
        "responses": ["I recommend 'The Alchemist' by Paulo Coelho.", "You might enjoy 'Inception' if you like sci-fi movies."]
    },
    {
        "tag": "hobbies",
        "patterns": [
            "What are some hobbies I can try?",
            "Suggest a hobby for me.",
            "What do you recommend for a hobby?"
        ],
        "responses": [
            "You could try painting, gardening, or learning a musical instrument.",
            "How about photography or hiking? Those are great hobbies!",
            "Reading, cooking, or even coding can be fun hobbies to explore."
        ]
    },
    {
        "tag": "motivation",
        "patterns": [
            "I need some motivation.",
            "Can you inspire me?",
            "Give me a motivational quote."
        ],
        "responses": [
            "Believe you can and you're halfway there. - Theodore Roosevelt",
            "Success is not final, failure is not fatal: It is the courage to continue that counts. - Winston Churchill",
            "The only way to do great work is to love what you do. - Steve Jobs"
        ]
    },
    {
        "tag": "health_tips",
        "patterns": [
            "Give me some health tips.",
            "How can I stay healthy?",
            "What should I eat to be healthy?"
        ],
        "responses": [
            "Make sure to drink plenty of water and eat a balanced diet rich in fruits and vegetables.",
            "Regular exercise and adequate sleep are key to maintaining good health.",
            "Consider incorporating more whole grains and lean proteins into your meals."
        ]
    },
    {
        "tag": "travel",
        "patterns": [
            "Where should I travel next?",
            "Suggest a travel destination.",
            "What are some good places to visit?"
        ],
        "responses": [
            "How about visiting Japan for its rich culture and delicious food?",
            "Consider exploring the beautiful landscapes of New Zealand.",
            "Italy is a great choice for its history, art, and cuisine."
        ]
    },
    {
        "tag": "technology",
        "patterns": [
            "What are the latest tech trends?",
            "Tell me about new gadgets.",
            "What should I know about AI?"
        ],
        "responses": [
            "Artificial Intelligence and machine learning are rapidly evolving fields.",
            "The latest trends include advancements in 5G technology and smart home devices.",
            "Wearable technology is becoming increasingly popular, with new health monitoring features."
        ]
    },
    {
        "tag": "fun_facts",
        "patterns": [
            "Tell me a fun fact.",
            "I want to learn something interesting.",
            "Share a random fact with me."
        ],
        "responses": [
            "Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3000 years old!",
            "Bananas are berries, but strawberries aren't!",
            "Octopuses have three hearts and blue blood."
        ]
    },
    {
        "tag": "personal_finance",
        "patterns": [
            "How can I save money?",
            "What are some budgeting tips?",
            "Tell me about investing."
        ],
        "responses": [
            "Start by tracking your expenses and creating a budget to identify areas where you can save.",
            "Consider setting up an emergency fund to cover unexpected expenses.",
            "Investing in index funds can be a good way to grow your wealth over time."
        ]
    },
    {
        "tag": "books_and_literature",
        "patterns": [
            "What book should I read?",
            "Recommend a good novel.",
            "What are some classic books?"
        ],
        "responses": [
            "You might enjoy 'Pride and Prejudice' by Jane Austen or '1984' by George Orwell.",
            "For a thrilling read, try 'The Girl on the Train' by Paula Hawkins.",
            "If you like fantasy, 'The Hobbit' by J.R.R. Tolkien is a classic."
        ]
    },
    {
        "tag": "movies_and_tv_shows",
        "patterns": [
            "What movie should I watch?",
            "Recommend a TV show.",
            "What are some good films?"
        ],
        "responses": [
            "If you're in the mood for a comedy, try 'The Office' or 'Parks and Recreation.'",
            "For a great movie, 'The Shawshank Redemption' is highly rated.",
            "If you like action, 'Mad Max: Fury Road' is a must-see."
        ]
    },
    {
        "tag": "learning_and_education",
        "patterns": [
            "What should I learn next?",
            "Suggest a course for me.",
            "How can I improve my skills?"
        ],
        "responses": [
            "Consider learning a new language or taking an online course in data science.",
            "Coding is a valuable skill; platforms like Codecademy can help you get started.",
            "You might also explore creative skills like graphic design or photography."
        ]
    },
    {
        "tag": "self_care",
        "patterns": [
            "What are some self-care tips?",
            "How can I take care of myself?",
            "Suggest some self-care activities."
        ],
        "responses": [
            "Take time to relax and unwind, whether it's through meditation or a warm bath.",
            "Engage in activities you enjoy, like reading or painting.",
            "Make sure to prioritize sleep and maintain a balanced diet."
        ]
    },
    {
        "tag": "environment",
        "patterns": [
            "How can I help the environment?",
            "What are some eco-friendly practices?",
            "Tell me about climate change."
        ],
        "responses": [
            "You can reduce waste by recycling and using reusable bags.",
            "Consider using public transport or biking instead of driving.",
            "Planting trees and conserving water are great ways to help the environment."
        ]
    },
    {
        "tag": "career_advice",
        "patterns": [
            "What should I do to advance my career?",
            "Give me some career tips.",
            "How can I improve my resume?"
        ],
        "responses": [
            "Networking is crucial; connect with professionals in your field.",
            "Consider taking courses to enhance your skills and knowledge.",
            "Tailor your resume to highlight relevant experience for each job application."
        ]
    },
    {
        "tag": "parenting",
        "patterns": [
            "What are some tips for parenting?",
            "How can I be a better parent?",
            "Give me advice on raising children."
        ],
        "responses": [
            "Be patient and listen to your child's needs.",
            "Establish routines to provide structure and security.",
            "Encourage open communication and be a positive role model."
        ]
    },
    {
        "tag": "fashion",
        "patterns": [
            "What are the latest fashion trends?",
            "Give me some fashion advice.",
            "How can I improve my style?"
        ],
        "responses": [
            "Layering is a great way to add depth to your outfit.",
            "Accessorizing can elevate even the simplest outfits.",
            "Don't be afraid to experiment with colors and patterns!"
        ]
    },
    {
        "tag": "pets",
        "patterns": [
            "What are some good pets to have?",
            "How do I take care of my pet?",
            "Give me advice on adopting a pet."
        ],
        "responses": [
            "Dogs and cats are popular pets, but consider your lifestyle when choosing.",
            "Make sure to provide proper nutrition, exercise, and regular vet check-ups.",
            "Adopting from a shelter is a great way to give a pet a loving home."
        ]
    },
    {
        "tag": "cooking",
        "patterns": [
            "What should I cook for dinner?",
            "Give me a recipe idea.",
            "How can I improve my cooking skills?"
        ],
        "responses": [
            "Try making a stir-fry with your favorite vegetables and protein.",
            "Experiment with new spices to enhance your dishes.",
            "Consider taking a cooking class to learn new techniques."
        ]
    },
    {
        "tag": "history",
        "patterns": [
            "Tell me about a historical event.",
            "What happened during World War II?",
            "Give me a fun fact about history."
        ],
        "responses": [
            "Did you know that the Great Wall of China was built over several dynasties?",
            "The signing of the Declaration of Independence occurred in 1776.",
            "Cleopatra was the last active ruler of the Ptolemaic Kingdom of Egypt."
        ]
    },
    {
        "tag": "sports",
        "patterns": [
            "What are the most popular sports?",
            "Tell me about a famous athlete.",
            "What sports should I try?"
        ],
        "responses": [
            "Soccer, basketball, and cricket are among the most popular sports worldwide.",
            "Michael Jordan is often regarded as one of the greatest basketball players of all time.",
            "Consider trying out for a local soccer or basketball team!"
        ]
    },
    {
        "tag": "entertainment",
        "patterns": [
            "What are some good entertainment options?",
            "Suggest something fun to do.",
            "What can I do for fun?"
        ],
        "responses": [
            "You could watch a movie, go to a concert, or visit a local museum.",
            "How about trying out a new board game or going for a hike?",
            "Consider attending a live performance or exploring a new hobby."
        ]
    },
    {
        "tag": "science",
        "patterns": [
            "Tell me something interesting about science.",
            "What are some recent scientific discoveries?",
            "Explain a scientific concept."
        ],
        "responses": [
            "Did you know that water can exist in three states: solid, liquid, and gas?",
            "The discovery of penicillin by Alexander Fleming revolutionized medicine.",
            "Quantum entanglement is a phenomenon where particles become interconnected."
        ]
    },
    {
        "tag": "culture",
        "patterns": [
            "What are some interesting cultural practices?",
            "Tell me about a unique tradition.",
            "What is a cultural festival I should know about?"
        ],
        "responses": [
            "The Day of the Dead in Mexico is a vibrant celebration honoring deceased loved ones.",
            "Holi, the festival of colors in India, celebrates the arrival of spring.",
            "The Japanese tea ceremony is a traditional ritual that emphasizes harmony and respect."
        ]
    },
    {
        "tag": "philosophy",
        "patterns": [
            "What is philosophy?",
            "Tell me about a famous philosopher.",
            "What are some philosophical questions?"
        ],
        "responses": [
            "Philosophy is the study of fundamental questions about existence, knowledge, and ethics.",
            "Socrates is known for his contributions to ethics and epistemology.",
            "Some philosophical questions include: What is the meaning of life? and Do we have free will?"
        ]
    },
    {
        "tag": "mythology",
        "patterns": [
            "Tell me about a mythological story.",
            "What are some famous myths?",
            "Who are the gods in Greek mythology?"
        ],
        "responses": [
            "In Greek mythology, Zeus is the king of the gods and ruler of Mount Olympus.",
            "The story of Hercules and his twelve labors is a well-known myth.",
            "Norse mythology features gods like Odin, Thor, and Loki."
        ]
    },
    {
        "tag": "fashion_history",
        "patterns": [
            "What are some historical fashion trends?",
            "Tell me about fashion in the 1920s.",
            "What influenced fashion in the past?"
        ],
        "responses": [
            "The 1920s saw the rise of flapper dresses and a more relaxed style for women.",
            "The Victorian era was characterized by corsets and elaborate dresses.",
            "Fashion has often been influenced by cultural movements and historical events."
        ]
    },
    {
        "tag": "gaming",
        "patterns": [
            "What are the best video games right now?",
            "Suggest a fun game to play.",
            "Tell me about popular gaming genres."
        ],
        "responses": [
            "Some popular games include 'The Legend of Zelda: Breath of the Wild' and 'Among Us.'",
            "Action-adventure, role-playing, and simulation are popular gaming genres.",
            "Consider trying out 'Minecraft' for a creative building experience."
        ]
    },
    {
        "tag": "food",
        "patterns": [
            "What are some popular dishes around the world?",
            "Suggest a recipe for dinner.",
            "Tell me about different cuisines."
        ],
        "responses": [
            "Italian cuisine is famous for pasta and pizza, while Indian cuisine is known for its spices.",
            "How about trying a stir-fry with vegetables and your choice of protein?",
            "Sushi is a popular Japanese dish that consists of vinegared rice and various ingredients."
        ]
    },
    {
        "tag": "current_events",
        "patterns": [
            "What are the current events?",
            "Tell me about the news today.",
            "What is happening in the world right now?"
        ],
        "responses": [
            "I can't provide real-time news, but you can check news websites for the latest updates.",
            "For current events, consider visiting BBC or CNN for reliable news coverage.",
            "Stay informed by following reputable news sources on social media."
        ]
    },
    {
        "tag": "life_advice",
        "patterns": [
            "Give me some life advice.",
            "What should I do when I'm feeling lost?",
            "How can I make better decisions?"
        ],
        "responses": [
            "Take time to reflect on your values and what truly matters to you.",
            "Don't be afraid to seek advice from trusted friends or mentors.",
            "Sometimes, taking a break and stepping back can provide clarity."
        ]
    }
]

# %%
vectorizer = TfidfVectorizer()
clf = LogisticRegression(random_state=0, max_iter=10000)

tags = []
patterns = []
for intent in intents:
    for pattern in intent['patterns']:
        tags.append(intent['tag'])
        patterns.append(pattern)

# %%
x = vectorizer.fit_transform(patterns)
y = tags
clf.fit(x, y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
def chatbot(input_text):
    # Input validation
    if not input_text or not isinstance(input_text, str):
        return "Please provide a valid input."
        
    cleaned_input = input_text.strip()
    if not cleaned_input:
        return"Please provide a valid input."

    try:
        input_text = vectorizer.transform([input_text])
        tag = clf.predict(input_text)[0]
        
        for intent in intents:
            if intent['tag'] == tag:
                response = random.choice(intent['responses'])
                return response
    except Exception as e:
        return f"An error occurred while processing your request: {e}"

# %%
user_input = "Hello"
response = chatbot(user_input)
print(response)
# Out:
# Hey

# %%
user_input = "budget"
response = chatbot(user_input)
print(response)
# Out:
# A good budgeting strategy is to use the 50/30/20 rule. This means allocating 50% of your income towards essential expenses, 30% towards discretionary expenses, and 20% towards savings and debt repayment.

# %%
user_input = "What are the best video games right now?"
response = chatbot(user_input)
print(response)
# Out:
# Some popular games include 'The Legend of Zelda: Breath of the Wild' and 'Among Us.'

# %%
user_input = "Give me some life advice."
response = chatbot(user_input)
print(response)
# Out:
# Don't be afraid to seek advice from trusted friends or mentors.

# %%
user_input = "What are some good pets to have?"
response = chatbot(user_input)
print(response)
# Out:
# Adopting from a shelter is a great way to give a pet a loving home.

# %%
user_input = "What should I cook for dinner?"
response = chatbot(user_input)
print(response)
# Out:
# Consider taking a cooking class to learn new techniques.

# %%
user_input = "Tell me about a mythological story."
response = chatbot(user_input)
print(response)
# Out:
# Norse mythology features gods like Odin, Thor, and Loki.

# %%
user_input = "What are some historical fashion trends?"
response = chatbot(user_input)
print(response)
# Out:
# The 1920s saw the rise of flapper dresses and a more relaxed style for women.

# %%
user_input = "What are some interesting cultural practices?"
response = chatbot(user_input)
print(response)
# Out:
# Holi, the festival of colors in India, celebrates the arrival of spring.

# %%
user_input = "What are some popular dishes around the world?"
response = chatbot(user_input)
print(response)
# Out:
# How about trying a stir-fry with vegetables and your choice of protein?

# %%
user_input = "What is philosophy?"
response = chatbot(user_input)
print(response)
# Out:
# Some philosophical questions include: What is the meaning of life? and Do we have free will?

# %%
user_input = "Suggest something fun to do"
response = chatbot(user_input)
print(response)
# Out:
# Consider attending a live performance or exploring a new hobby.

# %%
user_input = "What are some tips for parenting?"
response = chatbot(user_input)
print(response)
# Out:
# Be patient and listen to your child's needs.

# %%
user_input = "What are some eco-friendly practices?"
response = chatbot(user_input)
print(response)
# Out:
# Consider using public transport or biking instead of driving.

# %%
user_input = "What are some self-care tips?"
response = chatbot(user_input)
print(response)
# Out:
# Engage in activities you enjoy, like reading or painting.

# %%
user_input = 90
response = chatbot(user_input)
print(response)
# Out:
# Please provide a valid input.

# %%
user_input = ""
response = chatbot(user_input)
print(response)
# Out:
# Please provide a valid input.

# %%
user_input = "   "
response = chatbot(user_input)
print(response)
# Out:
# Please provide a valid input.
